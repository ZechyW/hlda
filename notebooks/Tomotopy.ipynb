# %%
# Tomotopy HLDA Test
import tomotopy as tp

import glob
import string
import re
import nltk

from ipywidgets import widgets
from IPython.core.display import HTML, display

# %%
# Config

# Random seed for training runs
model_seed = 7156

# Pre-processing (need to retrain if changed, of course)
extra_tokenise = True
do_stemming = True

# If train_and_save is False, will attempt to load from model_file instead
model_file = "bbc_model.bin"
train_and_save = False

# %%
# Tomotopy model
# N.B.: Will be overwritten below if train_and_save is False
model = tp.HLDAModel(seed=model_seed, depth=3)

# %%
# Ingest BBC data

# Stopwords
stopset = set(nltk.corpus.stopwords.words("english") + list(string.punctuation))
# Pronouns, titles
stopset.update(
    ["i", "i'm", "i'd", "i've", "i'll"]
    + ["she", "she's", "she'd", "she'll"]
    + ["he", "he's", "he'd", "he'll"]
    + ["they", "they're", "they'd", "they'll"]
    + ["mr", "dr"]
)
# Modals
stopset.update(["would", "could", "should", "shall", "can"])
# Corpus-specific
stopset.update(["will", "also", "said"])

# Stemming
if do_stemming:
    # Save a representative full token for each stem (for friendly display).
    # Each key -> 2nd level Dictionary of counts for full forms
    stem_to_word_count = {}
    stemmer = nltk.stem.snowball.SnowballStemmer("english")

# Iterate over data
for file in glob.glob("../bbc/tech/*.txt"):
    with open(file) as f:
        doc = f.read()

        # Remove unicode chars
        doc = doc.encode("ascii", "ignore").decode()

        # Case folding
        tokens = doc.casefold().split()

        # Preliminary removal of leading/trailing punctuation and stopwords
        tokens = [x.strip(string.punctuation) for x in tokens]
        tokens = [
            x
            for x in tokens
            if x and x not in stopset and not re.match(r"^(\W|\d)+$", x)
        ]

        # Extra tokenisation
        if extra_tokenise:
            clean = " ".join(tokens)
            tokens = nltk.word_tokenize(clean)
            # Secondary stopword cleaning
            tokens = [x.strip(string.punctuation) for x in tokens]
            tokens = [
                x
                for x in tokens
                if x and x not in stopset and not re.match(r"^(\W|\d)+$", x)
            ]

        # Stemming
        if do_stemming:
            new_tokens = []
            for token in tokens:
                stem = stemmer.stem(token)

                # Save friendly version
                if stem not in stem_to_word_count:
                    stem_to_word_count[stem] = {}
                if token not in stem_to_word_count[stem]:
                    stem_to_word_count[stem][token] = 1
                else:
                    stem_to_word_count[stem][token] += 1

                new_tokens.append(stem)

            tokens = new_tokens

        # Add to model
        model.add_doc(tokens)

# Flatten stem_to_word_count to the full word with the highest count
if do_stemming:
    stem_to_word = {}

    for stem, counts in stem_to_word_count.items():
        highest = ["", 0]
        for word, count in counts.items():
            if count > highest[1]:
                highest = [word, count]

        stem_to_word[stem] = highest[0]

# %%
# Model training / Load model file
if train_and_save:
    for i in range(0, 500, 50):
        model.train(50)
        print("Iteration: {}\tLog-likelihood: {}".format(i, model.ll_per_word))
    print(f"Saving to {model_file}.")
    model.save(model_file)
else:
    model = tp.HLDAModel.load(model_file)

# %% [markdown]
# Results
# =======

# %%
# Utils
def word_by_id(word_id):
    return model.vocabs[word_id]

# %%
# Results by topic
def print_with_parents(topic_id):
    # Recursively print any parents first
    parent_id = model.parent_topic(topic_id)
    if parent_id >= 0:
        print_with_parents(parent_id)

    # Print this topic
    words_probs = model.get_topic_words(topic_id, top_n=10)
    words = [x[0] for x in words_probs]

    # Lookup stem -> most common form if necessary
    if do_stemming:
        words = [stem_to_word[x] for x in words]

    words = ", ".join(words)
    print(f"Level {model.level(topic_id)}: {words}")


for k in range(model.k):
    if not model.is_live_topic(k):
        continue

    print(f"Topic {k}")
    print("=-=-=-=-=-=-=")
    print_with_parents(k)
    print()
# Out:
# Topic 0
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: spam, e-mail, mail, spammers, users, security, clicking, junk, anti-spam, bad
#
# Topic 74
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: tv, broadcast, digital, service, channels, programmes, television, viewers, market, launch
# Level 2: dtt, france, free-to-air, pay-tv, uk, tnt, reach, freeview, platform, optimistic
#
# Topic 75
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: games, play, titles, console, characters, control, gamers, machine, players, tweaked
# Level 2: models, hundreds, bioware, images, chosen, auditions, perry, head, 3d, seeking
#
# Topic 76
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: virus, phishing, attacks, messages, e-mail, number, security, hogan, spam, writers
#
# Topic 77
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: hip-hop, millan, rap, world, spanish, says, radio, latinohiphopradio.com, spain, one
#
# Topic 78
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: called, users, skype, service, net, phone, free, make, hotspots, broadband
#
# Topic 79
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: apple, journalists, information, source, eff, report, products, provide, legal, revealed
#
# Topic 80
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: robot, asimo, running, hitachi, honda, sony, qrio, humanoid, emiew, pal
#
# Topic 81
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: digital, divide, access, predicted, report, hosford, bt, internet, online, missed
#
# Topic 82
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: technology, body, clothes, electronics, smart, fabrics, skin, future, exploit, material
# Level 2: greenfield, pearson, contact, wrists, textiles, drugs, wearing, enhance, make-up, guide
#
# Topic 83
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: blogs, us, word, news, survey, media, web, political, journals, read
#
# Topic 84
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: mac, mini, apple, market, fogg, ipod, small, pc, sales, price
#
# Topic 85
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: images, create, resolution, dutch, photographs, viewers, taken, pictures, capture, panoramic
# Level 2: phone, mobile, pictures, camera, news, already, celebrities, snaps, newspapers, catch
#
# Topic 86
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: went, titles, finest, shooter, halo, pro, sweeping, blue, prince, rhythms
# Level 2: awards, best, games, interactive, bafta, year, film, category, entertainment, bbc
#
# Topic 87
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: rules, service, consumers, firm, mobile, phone, new, flynn, ringtones, get
#
# Topic 88
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: world, digital, access, divide, report, fund, countries, development, wsis, project
#
# Topic 89
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: went, titles, finest, shooter, halo, pro, sweeping, blue, prince, rhythms
#
# Topic 90
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: images, create, resolution, dutch, photographs, viewers, taken, pictures, capture, panoramic
#
# Topic 91
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: pandas, reserve, networks, world, wolong, wireless, staff, children, enable, observe
#
# Topic 92
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: argonaut, games, administrators, london, companies, cash, sales, staff, news, losses
#
# Topic 93
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: games, learning, sims, language, purushotma, believe, teach, students, world, teachers
#
# Topic 94
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: hunting, animals, rifle, texas, remote, control, net, session, fee, let
#
# Topic 95
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: use, people, games, technology, mobile, phone, one, new, service, year
#
# Topic 96
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: e-mail, fbi, virus, warned, attachment, recipients, computer, use, internet, messages
#
# Topic 97
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: bank, account, data, cards, personal, identity, customers, danger, financial, theft
#
# Topic 98
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: games, children, parents, industry, research, education, study, play, video, computer
#
# Topic 99
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: games, san, andreas, city, control, characters, set, upon, car, grand
# Level 2: games, learning, classroom, owen, school, education, futurelab, race, mainstream, teach
#
# Topic 100
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: cash, machine, bank, virus, windows, networks, operators, risks, atms, thiemann
# Level 2: iptv, telco, microsoft, tv, cable, channels, line, viewers, software, deal
#
# Topic 101
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: mac, mini, machine, computer, pc, apple, software, hard, small, basic
#
# Topic 102
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: project, tv, viewers, audience, allow, products, editing, moment, media, nm2
# Level 2: games, gamers, virtual, entropia, land, real, peds, money, island, sell
#
# Topic 103
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: jeeves, ask, blogs, bloglines, lanzone, search, site, entries, information, help
#
# Topic 104
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: documents, information, microsoft, word, sensitive, change, hidden, tool, editing, windows
#
# Topic 105
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: supercomputer, blue, machine, top, speed, simulator, gene/l, us, second, test
#
# Topic 106
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: control, people, research, brain, use, computer, cap, team, cursor, electrodes
# Level 2: tremor, computer, mouse, conditions, shake, foundation, britons, et, prototype, households
#
# Topic 107
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: wi-fi, security, wireless, networks, hotspots, net, found, london, users, warned
#
# Topic 108
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: net, security, women, virus, broadband, programs, threat, protect, study, goosens
#
# Topic 109
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: tv, broadcast, digital, service, channels, programmes, television, viewers, market, launch
# Level 2: media, china, foreign, joint, venture, investment, million, chinese, mobile, strong
#
# Topic 110
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: reddy, prof, says, think, computer, illiterate, pctvt, way, video, indian
# Level 2: maps, respond, satellite, group, need, aid, data, images, darfur, organisations
#
# Topic 111
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: games, play, titles, console, characters, control, gamers, machine, players, tweaked
# Level 2: xbox, allard, microsoft, details, makers, glimpse, interface, support, given, devices
#
# Topic 112
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: domain, fake, use, dyer, system, users, site, name, browser, website
#
# Topic 113
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: donate, help, aid, people, site, agency, web, online, organisations, relief
# Level 2: search, queries, engine, dogs, strange, type, enquiries, vacation, terms, dictate
#
# Topic 114
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: domain, site, e-mail, name, new, net, website, icann, dec, tsunami
#
# Topic 115
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: attacks, net, data, machine, site, traffic, criminals, networks, bot, many
#
# Topic 116
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: cartridges, printer, ink, hp, chip, cost, lawsuit, woman, inkjet, date
# Level 2: xbox, damage, consumers, cable, console, microsoft, advises, customers, replace, cord
#
# Topic 117
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: site, spam, lycos, screensaver, e-mail, attacks, campaign, traffic, service, website
#
# Topic 118
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: virus, e-mail, infected, anti-virus, messages, machine, spread, firm, christmas, address
#
# Topic 119
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: tv, broadcast, digital, service, channels, programmes, television, viewers, market, launch
# Level 2: broadband, iptv, bt, bbc, choice, content, interactive, burke, offer, conventional
#
# Topic 120
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: patents, software, ibm, open, source, linux, bill, european, law, programs
#
# Topic 121
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: apple, products, information, complaint, individual, lawsuit, leaked, future, post, files
# Level 2: computer, raskin, apple, use, macintosh, first, team, interface, machine, mac
#
# Topic 122
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: patents, directive, legal, software, european, inventions, programmes, infringed, council, ministers
# Level 2: content, regulation, tv, net, internet, consumers, curry, provide, ofcom, lord
#
# Topic 123
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: argonaut, games, administrators, london, companies, cash, sales, staff, news, losses
# Level 2: games, studios, makers, molyneux, industry, honour, thought, population, lionhead, computer
#
# Topic 124
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: file-sharing, court, betamax, rules, innovation, industry, supreme, response, music, case
#
# Topic 125
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: alert, service, security, home, computer, software, tell, safe, government, national
#
# Topic 126
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: law, patents, eu, directive, software, european, inventions, parliament, says, ministers
#
# Topic 127
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: bloggers, blogs, day, sigarchi, iranian, hopkins, iran, arash, action, mojtaba
# Level 2: community, public, online, government, common, debate, role, policy, ippr, bbc
#
# Topic 128
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: bruvik, court, norway, files, norwegian, site, links, pay, legal, submitted
# Level 2: games, gamers, casual, titles, attractive, play, panel, mobile, hardcore, demographics
#
# Topic 129
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: broadband, tv, price, number, found, analysts, service, months, supplier, biggest
#
# Topic 130
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: phone, scams, companies, premium, customers, number, bill, bt, called, diallers
#
# Topic 131
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: games, development, console, next, machine, new, microsoft, generation, mobile, ea
#
# Topic 132
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: world, digital, access, divide, report, fund, countries, development, wsis, project
# Level 2: fixed-line, use, people, games, technology, mobile, phone, one, new, service
#
# Topic 133
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: blogs, service, microsoft, msn, journals, web, free, existing, google, aol
#
# Topic 134
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: seafarers, cards, data, monitor, store, id, biometric, security, issues, ship
#
# Topic 135
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: phone, mobile, handsets, use, fixed, called, goodman, old, questions, line
#
# Topic 136
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: software, us, dod, internet, crack, computer, code, profit, claimed, boyd
#
# Topic 137
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: games, san, andreas, city, control, characters, set, upon, car, grand
#
# Topic 138
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: mail, junk, spam, e-mail, techniques, spamhaus, machine, spammers, filters, hogan
#
# Topic 139
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: robot, human, react, might, companion, learning, team, dautenhahn, professor, museum
#
# Topic 140
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: simonetti, airline, ms, blogs, delta, images, sky, employees, suspended, companies
#
# Topic 141
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: donate, help, aid, people, site, agency, web, online, organisations, relief
#
# Topic 143
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: games, everything, feel, impressive, genre, annoyances, perfect, products, scientists, surface
#
# Topic 144
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: windows, microsoft, security, software, users, pcs, flaws, virus, critical, patches
#
# Topic 145
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: bloggers, blogs, day, sigarchi, iranian, hopkins, iran, arash, action, mojtaba
# Level 2: sentenced, arrested, online, without, revolutionary, weblogger, borders, jail, harsh, criticised
#
# Topic 146
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: players, broadband, mp3, million, access, american, net, found, people, one
#
# Topic 147
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: browser, firefox, microsoft, version, opera, ie, internet, released, voice, security
#
# Topic 148
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: tv, broadcast, digital, service, channels, programmes, television, viewers, market, launch
# Level 2: mobile, handsets, korea, dmb, korean, chip, two, south, may, 3gsm
#
# Topic 149
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: school, connection, project, e-slates, eduvision, satellite, students, information, herren, handheld
#
# Topic 150
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: beckham, trojan, messages, open, infected, interest, life, catch, private, appear
#
# Topic 151
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: patents, directive, legal, software, european, inventions, programmes, infringed, council, ministers
# Level 2: proposals, rejected, parliament, amazon, goes, damage, controversial, defences, source, child
#
# Topic 153
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: robot, human, react, might, companion, learning, team, dautenhahn, professor, museum
# Level 2: creative, technology, games, art, industry, bt, engine, stone, idea, river
#
# Topic 154
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: light, use, silicon, laser, intel, make, chip, paniccia, material, data
# Level 2: libraries, book, google, oxford, scan, world, public, university, online, digitised
#
# Topic 155
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: yahoo, search, google, web, internet, portal, weiner, dot-com, content, brand
# Level 2: yang, firm, jerry, decade, anniversary, investment, april, celebrities, students, remarkable
#
# Topic 156
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: sun, computer, grid, hours, system, service, use, capacity, power, customers
#
# Topic 157
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: p2p, networks, files, music, peer-to-peer, industry, piracy, copyright, us, download
#
# Topic 158
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: images, create, resolution, dutch, photographs, viewers, taken, pictures, capture, panoramic
# Level 2: project, visitors, life, computer-generated, software, computer, digital, combination, view, camera
#
# Topic 159
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: recycling, power, energy, aware, electronics, consumers, epa, efficient, billion, mobile
#
# Topic 160
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: spyware, microsoft, programs, software, users, computer, anti-virus, security, anti-spyware, tool
#
# Topic 161
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: control, people, research, brain, use, computer, cap, team, cursor, electrodes
# Level 2: grid, project, donate, research, health, task, address, board, volunteers, folding
#
# Topic 162
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: games, play, titles, console, characters, control, gamers, machine, players, tweaked
# Level 2: psp, sony, movies, umd, japan, games, film, playstation, halo, portable
#
# Topic 163
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: mail, junk, spam, e-mail, techniques, spamhaus, machine, spammers, filters, hogan
# Level 2: telewest, offer, sky, programmes, record, tv, pvr, video-on-demand, box, cable
#
# Topic 164
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: games, fans, titles, within, perhaps, feel, gameplay, present, flair, satisfying
# Level 2: lifts, record, tower, world, speed, tfc, elevators, guinness, passengers, fastest
#
# Topic 165
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: podcasting, radio, curry, says, listen, show, create, automatically, ipod, interest
#
# Topic 166
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: search, google, engine, site, speegle, speech, web, blind, renton, surfers
# Level 2: broadband, connection, daily, fast, dial-up, modem, speed, weather, check, anne
#
# Topic 167
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: search, desktop, microsoft, google, software, blinkx, users, engine, tool, site
#
# Topic 168
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: light, use, silicon, laser, intel, make, chip, paniccia, material, data
# Level 2: laser, networks, tata, set, speed, bridge, firm, digging, permission, help
#
# Topic 169
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: light, use, silicon, laser, intel, make, chip, paniccia, material, data
# Level 2
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: mail, junk, spam, e-mail, techniques, spamhaus, machine, spammers, filters, hogan
# Level 2: net, standard, carpenter, address, next, ietf, ipv6, growth, challenge, protocol
#
# Topic 194
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: games, san, andreas, city, control, characters, set, upon, car, grand
# Level 2: phone, mobile, cab, lose, lost, gadget, back-up, according, left, back
#
# Topic 195
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: light, use, silicon, laser, intel, make, chip, paniccia, material, data
# Level 2: power, laptop, battery, trainor, energy, need, life, consumption, ion, notebook
#
# Topic 196
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: donate, help, aid, people, site, agency, web, online, organisations, relief
# Level 2: messages, says, blogs, text, morquendi, world, tsunami, bloggers, friends, disaster
#
# Topic 197
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: chip, cell, processor, sony, playstation, computer, year, ibm, console, intel
#
# Topic 198
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: wars, elements, xbox, familiar, knights, joined, characters, jungle, final, original
# Level 2: awards, sony, pc, pro, innovation, products, trotter, magazine, prize, design
#
# Topic 199
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: pandas, reserve, networks, world, wolong, wireless, staff, children, enable, observe
# Level 2: clock, conducted, federal, province, bamboo, games, technology, mobile, phone, one
#
# Topic 200
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: gadget, radio, devices, design, video, awards, chair, technology, digital, consumers
#
# Topic 201
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: use, people, games, technology, mobile, phone, one, new, service, year
# Level 2: libraries, british, wireless, visitors, study, hotspots, caf, consultancy, extensive, public
#
# Topic 202
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: world, digital, access, divide, report, fund, countries, development, wsis, project
# Level 2: service, relay, deaf, phone, bsl, sign, language, called, video, rnid
#
# Topic 203
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: search, google, engine, site, speegle, speech, web, blind, renton, surfers
# Level 2: programmes, tv, channels, let, austria, local, watch, video, telekom, film
#
# Topic 204
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: computer, system, programs, firm, consumers, apple, use, files, gadget, security
# Level 2: games, copies, valve, half-life, top, titles, released, account, sales, system
#
# Topic 207
# =-=-=-=-=-=-=
# Level 0: people, use, one, technology, make, get, year, like, new, way
# Level 1: games, san, andreas, city, control, characters, set, upon, car, grand
# Level 2: high-definition, dvd, film, dean, dvds, means, studios, compression, work, home

# %%
# Interactive results by document

colour_map = {0: "blue", 1: "red", 2: "green"}

# Topic -> Level and Topic -> Top words mappings
topic_to_level = {}
topic_to_words = {}
for k in range(model.k):
    # Level
    if not model.is_live_topic(k):
        continue
    topic_to_level[k] = model.level(k)

    # Top words
    word_probs = model.get_topic_words(k, top_n=10)
    words = [x[0] for x in word_probs]

    # Lookup stem -> most common form if necessary
    if do_stemming:
        words = [stem_to_word[x] for x in words]

    topic_to_words[k] = words

# Each document
def show_doc(d=0):
    doc = model.docs[d]
    # Get unique doc topics -- Should be in ascending order of level after sorting
    doc_topics = list(set(doc.topics))
    doc_topics.sort()

    # Header
    for level in range(len(doc_topics)):
        output = (
            f"<h{level+1}><span style='color:{colour_map[level]}'>"
            f"Topic {doc_topics[level]} (Level {level}): "
            f"{', '.join(topic_to_words[doc_topics[level]])}"
            f"</span></h{level+1}>"
        )
        display(HTML(output))

    display(HTML("<hr/><h5>Processed Document</h5>"))

    # Documents words
    words = [word_by_id(x) for x in doc.words]
    if do_stemming:
        words = [stem_to_word[x] for x in words]

    word_html = []
    for word, topic in zip(words, doc.topics):
        word_html.append(
            f"<span style='color: {colour_map[topic_to_level[topic]]}'>{word}</span>"
        )

    display(HTML(" ".join(word_html)))

# %%
widgets.interact(show_doc, d=(0, len(model.docs) - 1))
# Out:
# interactive(children=(IntSlider(value=0, description='d', max=400), Output()), _dom_classes=('widget-interact'…
# <function __main__.show_doc(d=0)>
